# %%
st = 'Sam Print only the words that start with s in this sentence'

# %%
for word in st.split():
   # if word[0]=='s' or word[0]=='S':
   if word[0].lower() == 's': 
    print(word)
# Out:
# Sam
# start
# s
# sentence

# %%
list(range(0,10,2))
# Out:
# [0, 2, 4, 6, 8]

# %%
[x for x in range(1,50) if x%3==0]
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %%
st = 'Print every word in this sentence that has an even number of letters'
for word in st.split():
    if len(word)%2==0:
     print(word,"..has even number of letter")
# Out:
# word ..has even number of letter
# in ..has even number of letter
# this ..has even number of letter
# sentence ..has even number of letter
# that ..has even number of letter
# an ..has even number of letter
# even ..has even number of letter
# number ..has even number of letter
# of ..has even number of letter

# %%
for num in range(1,101):
    if num%3==0 and num%5==0:
        print(num," FizzBizz")
    elif num%3==0:
        print(num, " Fizz")
    elif num%5==0:
        print(num," Bizz")
    else:
        print(num)
# Out:
# 1
# 2
# 3  Fizz
# 4
# 5  Bizz
# 6  Fizz
# 7
# 8
# 9  Fizz
# 10  Bizz
# 11
# 12  Fizz
# 13
# 14
# 15  FizzBizz
# 16
# 17
# 18  Fizz
# 19
# 20  Bizz
# 21  Fizz
# 22
# 23
# 24  Fizz
# 25  Bizz
# 26
# 27  Fizz
# 28
# 29
# 30  FizzBizz
# 31
# 32
# 33  Fizz
# 34
# 35  Bizz
# 36  Fizz
# 37
# 38
# 39  Fizz
# 40  Bizz
# 41
# 42  Fizz
# 43
# 44
# 45  FizzBizz
# 46
# 47
# 48  Fizz
# 49
# 50  Bizz
# 51  Fizz
# 52
# 53
# 54  Fizz
# 55  Bizz
# 56
# 57  Fizz
# 58
# 59
# 60  FizzBizz
# 61
# 62
# 63  Fizz
# 64
# 65  Bizz
# 66  Fizz
# 67
# 68
# 69  Fizz
# 70  Bizz
# 71
# 72  Fizz
# 73
# 74
# 75  FizzBizz
# 76
# 77
# 78  Fizz
# 79
# 80  Bizz
# 81  Fizz
# 82
# 83
# 84  Fizz
# 85  Bizz
# 86
# 87  Fizz
# 88
# 89
# 90  FizzBizz
# 91
# 92
# 93  Fizz
# 94
# 95  Bizz
# 96  Fizz
# 97
# 98
# 99  Fizz
# 100  Bizz

# %%
st = 'Create a list of the first letters of every word in this string'
[word[0] for word in st.split()]
# Out:
# ['C', 'a', 'l', 'o', 't', 'f', 'l', 'o', 'e', 'w', 'i', 't', 's']
